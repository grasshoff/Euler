# %% [markdown]
# # Making a DataFrame Containing Euler's Publications from Webpage

# %% [markdown]
# ## Makes usable screen bigger

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Packages & definitions

# %%
# Necessary packages:
import requests
import re
import os
import shutil
import sys
import pandas as pd
pd.set_option("display.max_colwidth", 500)
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 1000)

# If not yet installed, install these packages now:
try:
    from bs4 import BeautifulSoup as bs
    import PyPDF2
except ImportError:
    os.system('python -m pip install bs4')
    os.system('python -m pip install PyPDF2')
    from bs4 import BeautifulSoup as bs
    import PyPDF2

# %%
def makeSoup(url):
    response = requests.get(url).content
    soup = bs(response, 'html.parser')
    return soup

# %%
def findPub(soup):
    pubs = soup.find_all(id="series-home")[0]
    publist = pubs.find_all(class_="article-listing")
    pdfs = pubs.find_all(class_="pdf")
    pdfurls = []
    pdfnumbers = []
    n = 0
    for pdf in pdfs:
        pdfurls.append(pdf.a['href'])
        pdfnumbers.append(str(int(pdf.a['href'].split('=')[1].split('&')[0][1:])+1))
        n = n + 1
    urls = []
    titles = []
    numbers = []
    for pub in publist:
        urls.append(pub.a['href'])
        titles.append(re.sub(r'E\d{1,3}: ', '', pub.get_text().replace('&pm', '±')))
        try:
            numbers.append(str(int(pub.get_text().split(': ')[0].replace('E', ''))))
        except: 
            numbers.append('870')
    return pdfurls, pdfnumbers, urls, titles, numbers

# %%
def findInfo(soup):
    pubs = soup.find_all(id="alpha")[0]
    headings = pubs.find_all('h4')
    for i in range(len(headings)):
        headings[i] = headings[i].get_text()
    texts = pubs.find_all(class_="element")
    for i in range(len(texts)):
        l = []
        for j in texts[i].find_all('p'):
            try:
                l.append(j.get_text())
            except:
                try:
                    l.append(j.a.get_text())
                except:
                    l.append(j.a.strong.get_text())
        texts[i] = l

    return headings, texts

# %% [markdown]
# ## Grapping all publications

# %%
arcUrlList = ['https://scholarlycommons.pacific.edu/euler-works/index.html'] + ['https://scholarlycommons.pacific.edu/euler-works/index.' + str(i) + '.html' for i in range(2,10)]

# %%
soupsPages = [makeSoup(url) for url in arcUrlList]

# %%
pdfurls = []
pdfnumbers = []
urls = []
titles = []
numbers = []
for soup in soupsPages:
    pdfurl, pdfnumber, url, title, number = findPub(soup)
    pdfurls = pdfurls + pdfurl
    pdfnumbers = pdfnumbers + pdfnumber
    urls = urls + url
    titles = titles + title
    numbers = numbers + number

# %%
dfPDF = pd.DataFrame({'URLpdf': pdfurls, 'number': pdfnumbers})
dfPub = pd.DataFrame({'URLinfo': urls, 'title': titles, 'number': numbers})
dfEulers = dfPub.merge(dfPDF, 'outer', 'number')

# %%
dfEulers.URLpdf[220] = dfEulers.URLpdf[867]
dfEulers = dfEulers[:-1]

# %% [markdown]
# ## Gathering all the information about the publications

# %%
urllist = list(dfEulers.URLinfo)

# %%
# This step takes quite a while for all publications by Euler. Be prepared to wait!
soups = [makeSoup(url) for url in urllist]

# %%
headings_ = []
texts_ = []

for soup in soups:
    headings, texts = findInfo(soup)
    headings_ = headings_ + [headings]
    texts_ = texts_ + [texts]

# %%
infos = []
for i in range(len(headings_)):
    info = {}
    for j in range(len(headings_[i])):
        info[headings_[i][j]] = '\n'.join(texts_[i][j]).strip('\n')
    infos.append(info)

# %%
dfInfo = pd.DataFrame(infos)
dfEuler = dfEulers.join(dfInfo)

# %%
dfEuler = dfEuler[['Enestrom Number', 'Fuss Index', 'Title', 'English Title',
       'Authors', 'Original Language', 'Published as',
       'Published Date', 'Written Date', 'Original Source Citation', 'Archive Notes',
       'Content Summary', 'Opera Omnia Citation', 'Record Created','URLinfo', 'URLpdf']]

# %%
dfEuler['Enestrom Number'] = pd.to_numeric(dfEuler['Enestrom Number'])
dfEuler['Published Date'] = pd.to_numeric(dfEuler['Published Date'])
#dfEuler['Written Date'] = pd.to_numeric(dfEuler['Written Date'])
dfEuler['Record Created'] = pd.to_datetime(dfEuler['Record Created'], format='%Y-%m-%d')

# %%
dfEuler
# Out:
#      Enestrom Number Fuss Index  \
# 0                1.0        NaN
# 1                2.0        500
# 2                3.0        NaN
# 3                4.0        601
# 4                5.0        387
# ..               ...        ...
# 862            863.0        NaN
# 863            864.0        NaN
# 864            865.0        NaN
# 865            866.0        NaN
# 866              NaN        NaN
#
#                                                                                                           Title  \
# 0                                               Constructio linearum isochronarum in medio quocunque resistente
# 1                                                                                   Dissertatio physica de sono
# 2                                                       Methodus inveniendi traiectorias reciprocas algebraicas
# 3    Meditationes super problemate nautico, quod illustrissima regia Parisiensis Academia Scientiarum proposuit
# 4                                                               Problematis traiectoriarum reciprocarum solutio
# ..                                                                                                          ...
# 862                                               Seventeen letters from Euler to Johann I Bernoulli, 1727-1740
# 863                                                     Three letters from Euler to Daniel Bernoulli, 1734-1740
# 864                  Several lines of a letter from Euler to the Royal Society dated 21 October/1 November 1768
# 865                                                                              Ein Brief Eulers an d'Alembert
# 866                                                                                         De causa gravitatis
#
#                                                                                       English Title  \
# 0                                          Construction of isochronous curves in a resistant medium
# 1                                                                    Physical dissertation on sound
# 2                                                 On a method for algebraic reciprocal trajectories
# 3    Thoughts on a nautical problem, proposed by the illustrious Royal Academy of Sciences in Paris
# 4                                                Solution to the problem of reciprocal trajectories
# ..                                                                                              ...
# 862                                   Seventeen letters from Euler to Johann I Bernoulli, 1727-1740
# 863                                         Three letters from Euler to Daniel Bernoulli, 1734-1740
# 864      Several lines of a letter from Euler to the Royal Society dated 21 October/1 November 1768
# 865                                                               A letter from Euler to d'Alembert
# 866                                                                         On the cause of gravity
#
#             Authors Original Language         Published as  Published Date  \
# 0    Leonhard Euler             Latin      Journal article            1726
# 1    Leonhard Euler             Latin          Quarto book            1727
# 2    Leonhard Euler             Latin      Journal article            1727
# 3    Leonhard Euler             Latin  Paris prize article            1728
# 4    Leonhard Euler             Latin      Journal article            1729
# ..              ...               ...                  ...             ...
# 862  Leonhard Euler     Latin, German     Published letter            1740
# 863  Leonhard Euler            German     Published letter            1907
# 864  Leonhard Euler           English     Published letter            1908
# 865  Leonhard Euler            French     Published letter            1911
# 866  Leonhard Euler             Latin      Journal article            1743
#
#     Written Date  \
# 0           1725
# 1           1727
# 2           1727
# 3           1726
# 4           1728
# ..           ...
# 862         1740
# 863         1740
# 864         1768
# 865         1748
# 866          NaN
#
#                                                                                                          Original Source Citation  \
# 0                                                                                      Acta Eruditorum, Volume 1726, pp. 361-363.
# 1                                                                     Basel: E. and J. R. Thurnisiorum, Volume 1727, pp. 208-226.
# 2                                                                                      Acta Eruditorum, Volume 1727, pp. 408-412.
# 3                                        Pièce qui ont remporté le prix de l'académie royale des sciences, Volume 1727, pp. 1-48.
# 4                                                         Commentarii academiae scientiarum Petropolitanae, Volume 2, pp. 90-111.
# ..                                                                                                                            ...
# 862                                                                                                      Bibliotheca Mathematica.
# 863                                                                                Bibliotheca Mathematica, pp. 134-141, 145-153.
# 864  The Royal Society. Some accounts of the letters and papers of the period 1741-1806 in the archives, by A. H. Church, pp. 16.
# 865                                                                              Bibliotheca Mathematica, Volume 11, pp. 223-226.
# 866                                                                              Miscellanea Berolinensia, Volume 7, pp. 360-370.
#
#                                                                                                                                                                                                                                                                                                                                                   Archive Notes  \
# 0                                                                                                                                                                                                                                                                                                                                                           NaN
# 1               Euler wrote this Habilitation thesis as part of his application to the Physics chair of the University of Basel in 1727 (it was customary to present a paper of one's research, to demonstrate that one might be of service to the institution). It was reprinted in 1751 in a collection of papers edited by Albrecht von Haller in Göttingen.
# 2                                                                                                                                                                                                                                                                                                                                                           NaN
# 3                                                                                                                                                                                                                                                                                                                                                           NaN
# 4                                                                                                                                                                                                                                                                                                                                                           NaN
# ..                                                                                                                                                                                                                                                                                                                                                          ...
# 862  This is an unusual item in Eneström's index, in that it originally appeared in three different volumes of the same journal. Eneström states (as of 1913) that the original letters are in the library of the Swedish Academy of Sciences in Stockholm. E863 is missing page 67 from part 3 (each part has different page numbering) in the original scans.
# 863                                                                                                                                                                                                                                                        According to Eneström (as of 1913), the originals may be found in the Herzoglichen Library in Gotha.
# 864                                                                                                                                                                                                                                                                                  This work is likely a translation of Euler's original letter into English.
# 865                                                                                                                                                                                                                                                                                                                                                         NaN
# 866                                                                                                                                                         This work is not included in Eneström's index. Euler's authorship is confirmed in Note 13 of the Euler/Goldbach correspondence, with a reference to the introduction to O.II/31, pp. LXXXVII–XCIII.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Content Summary  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 1                                                                                                                                                                                         Euler first explains his theory of what makes up the atmosphere; the basis of his theory lies in the theory of elasticity of the teacher he had before Johann Bernoulli. He also states (without proof) a formula for the speed of propagation and derives from it numerical values of the correct order of magnitude for air.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 3    Euler uses mechanics to design ships. He adopts Newton's law of resistance (which says that the pressure exerted by a fluid acting against a plane surface is proportional to the square of the speed, neglecting back pressure) by interpreting it as a statement about differential elements of surface. He calls this assumption "the common hypothesis" and uses it to calculate the total resistance, via integration. In this way, he arrives at definite answers (often in elegant, explicit forms) that ...
# 4                                                                                                                                                                                                                                                                                               This article contains Euler's first published use of complex numbers and a many-axis geometric construction. Euler also defines even functions f(x) as those for which f(x) = f(-x), perhaps the first use of this term.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 862                               The seventeen letters written by Euler are dated 5 November 1727, 10 December 1728*, 18 February 1729*, 16 May 1729*, 21 October 1729, 11 July 1730*, 25 May 1731, 27 August 1737*, 10 December 1737*, 26 April 1738, 30 July 1738, 20 December 1738, 5 May 1739, 15 September 1739*, 19 January 1740*, 20 June 1740*, 18 October 1740*. The dates marked with a * indicate that an extract from the letter had been published earlier (in particular, see E64, E859, E861, and E862).
# 863                                                                                                                                                                                                                                                                                                                               As the title suggests, this is a collection of three letters from Euler to Daniel Bernoulli. The letters in question are dated 16 February 1734, November 1734, and 15 September 1740.
# 864                                                                                                                                                                                                                                                                                                                                                                                                                                           This letter concerns dioptrics and lunar theory, and is identical to E364.
# 865                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 866                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
#
#                 Opera Omnia Citation Record Created  \
# 0        Series 2, Volume 6, pp.1-3.     2018-09-25
# 1    Series 3, Volume 1, pp.181-196.     2018-09-25
# 2       Series 1, Volume 27, pp.1-5.     2018-09-25
# 3      Series 2, Volume 20, pp.1-35.     2018-09-25
# 4      Series 1, Volume 27, pp.6-23.     2018-09-25
# ..                               ...            ...
# 862                              NaN     2018-09-25
# 863                              NaN     2018-09-25
# 864                              NaN     2018-09-25
# 865                              NaN     2018-09-25
# 866                              NaN     2018-09-25
#
#                                                   URLinfo  \
# 0      https://scholarlycommons.pacific.edu/euler-works/1
# 1      https://scholarlycommons.pacific.edu/euler-works/2
# 2      https://scholarlycommons.pacific.edu/euler-works/3
# 3      https://scholarlycommons.pacific.edu/euler-works/4
# 4      https://scholarlycommons.pacific.edu/euler-works/5
# ..                                                    ...
# 862  https://scholarlycommons.pacific.edu/euler-works/863
# 863  https://scholarlycommons.pacific.edu/euler-works/864
# 864  https://scholarlycommons.pacific.edu/euler-works/865
# 865  https://scholarlycommons.pacific.edu/euler-works/866
# 866  https://scholarlycommons.pacific.edu/euler-works/870
#
#                                                                                         URLpdf
# 0    https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1000&context=euler-works
# 1    https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1001&context=euler-works
# 2    https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1002&context=euler-works
# 3    https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1003&context=euler-works
# 4    https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1004&context=euler-works
# ..                                                                                         ...
# 862  https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1862&context=euler-works
# 863  https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1863&context=euler-works
# 864  https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1864&context=euler-works
# 865  https://scholarlycommons.pacific.edu/cgi/viewcontent.cgi?article=1865&context=euler-works
# 866                                                                                        NaN
#
# [867 rows x 16 columns]

# %% [markdown]
# ## Store the DataFrame

# %%
#dfEuler.to_csv('./data/dfEulerPub_v1.csv', sep = ';', index=False)
